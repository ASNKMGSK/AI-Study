# %% [markdown]
# # G.04 이미지 어디까지 우려볼까?

# %% [markdown]
# ## 4.1 Augmentation을 적용한 데이터셋 만들기

# %%
# 필요한 라이브러리를 import 한다
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

import tensorflow_datasets as tfds

# %%
# GPu가 잘 돌아가는지 확인해본다
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# 데이터셋을 불러온다
import urllib3
urllib3.disable_warnings()
(ds_train, ds_test), ds_info = tfds.load(
    'stanford_dogs',
    split=['train', 'test'],
    shuffle_files=True,
    with_info=True,
)

# %%
# 잘 불러왔는지 확인해보자
fig = tfds.show_examples(ds_train, ds_info)

# %%
# 필요한 함수를 만든다
def normalize_and_resize_img(image, label):
    """Normalizes images: `uint8` -> `float32`."""
    image = tf.image.resize(image, [224, 224])
    return tf.cast(image, tf.float32) / 255., label

def augment(image,label):
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_brightness(image, max_delta=0.2)
    return image,label

def apply_normalize_on_dataset(ds, is_test=False, batch_size=16, with_aug=False, with_cutmix=False, with_mixup=False):
    ds = ds.map(
        normalize_and_resize_img, 
        num_parallel_calls=2
    )
    
    if not is_test and with_aug:
        ds = ds.map(
            augment
        )
    ds = ds.batch(batch_size)
    if not is_test and with_cutmix:
        ds = ds.map(
            cutmix,
            num_parallel_calls=2
        )
    elif not is_test and with_mixup:
        ds = ds.map(
            mixup,
            num_parallel_calls=2
        )
    else:
        ds = ds.map(
            onehot,
            num_parallel_calls=2
        )
    if not is_test:
        ds = ds.repeat()
        ds = ds.shuffle(200)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
    return ds

# %%
# Cumix 함수
def get_clip_box(image_a, image_b, img_size=224):
    # get center of box
    x = tf.cast( tf.random.uniform([],0, img_size),tf.int32)
    y = tf.cast( tf.random.uniform([],0, img_size),tf.int32)

    # get width of box
    _prob = tf.random.uniform([],0,1)
    width = tf.cast(img_size * tf.math.sqrt(1-_prob),tf.int32)
    
    # clip box in image and get minmax bbox
    xa = tf.math.maximum(0, x-width//2)
    ya = tf.math.maximum(0, y-width//2)
    yb = tf.math.minimum(img_size, y+width//2)
    xb = tf.math.minimum(img_size, x+width//2)
    
    return xa, ya, xb, yb

def mix_2_images(image_a, image_b, xa, ya, xb, yb, img_size=224):
    one = image_a[ya:yb,0:xa,:]
    two = image_b[ya:yb,xa:xb,:]
    three = image_a[ya:yb,xb:img_size,:]
    middle = tf.concat([one,two,three],axis=1)
    top = image_a[0:ya,:,:]
    bottom = image_a[yb:img_size,:,:]
    mixed_img = tf.concat([top, middle, bottom],axis=0)
    
    return mixed_img

def mix_2_label(label_a, label_b, xa, ya, xb, yb, img_size=224, num_classes=120):
    mixed_area = (xb-xa)*(yb-ya)
    total_area = img_size*img_size
    a = tf.cast(mixed_area/total_area, tf.float32)

    if len(label_a.shape)==0:
        label_a = tf.one_hot(label_a, num_classes)
    if len(label_b.shape)==0:
        label_b = tf.one_hot(label_b, num_classes)
    mixed_label = (1-a)*label_a + a*label_b
    return mixed_label

def cutmix(image, label, prob = 1.0, batch_size=16, img_size=224, num_classes=120):
    mixed_imgs = []
    mixed_labels = []

    for i in range(batch_size):
        image_a = image[i]
        label_a = label[i]
        j = tf.cast(tf.random.uniform([],0, batch_size),tf.int32)
        image_b = image[j]
        label_b = label[j]
        xa, ya, xb, yb = get_clip_box(image_a, image_b)
        mixed_imgs.append(mix_2_images(image_a, image_b, xa, ya, xb, yb))
        mixed_labels.append(mix_2_label(label_a, label_b, xa, ya, xb, yb))

    mixed_imgs = tf.reshape(tf.stack(mixed_imgs),(batch_size, img_size, img_size, 3))
    mixed_labels = tf.reshape(tf.stack(mixed_labels),(batch_size, num_classes))
    return mixed_imgs, mixed_labels

# %%
# Mixup 함수
def mixup_2_images(image_a, image_b, label_a, label_b):
    a = tf.random.uniform([],0,1)
    
    if len(label_a.shape)==0:
        label_a = tf.one_hot(label_a, num_classes)
    if len(label_b.shape)==0:
        label_b = tf.one_hot(label_b, num_classes)
    mixed_image= (1-a)*image_a + a*image_b
    mixed_label = (1-a)*label_a + a*label_b
    
    return mixed_image, mixed_label

def mixup(image, label, prob = 1.0, batch_size=16, img_size=224, num_classes=120):
    mixed_imgs = []
    mixed_labels = []

    for i in range(batch_size):
        image_a = image[i]
        label_a = label[i]
        j = tf.cast(tf.random.uniform([],0, batch_size),tf.int32)
        image_b = image[j]
        label_b = label[j]
        mixed_img, mixed_label = mixup_2_images(image_a, image_b, label_a, label_b)
        mixed_imgs.append(mixed_img)
        mixed_labels.append(mixed_label)

    mixed_imgs = tf.reshape(tf.stack(mixed_imgs),(batch_size, img_size, img_size, 3))
    mixed_labels = tf.reshape(tf.stack(mixed_labels),(batch_size, num_classes))
    return mixed_imgs, mixed_labels

# %%
# 원-핫 인코딩 함수
def onehot(image, label, prob = 1.0, batch_size=16, img_size=224, num_classes=120):
    imgs = []
    labels = []
    
    for i in range(batch_size):
        imgs.append(image[i])
        labels.append(tf.one_hot(label[i], num_classes))
    
    imgs = tf.reshape(tf.stack(imgs), (batch_size, img_size, img_size, 3))
    return imgs, labels

# %%
num_classes = ds_info.features['label'].num_classes

# %% [markdown]
# ## 4.2 모델 만들기

# %%
# 그냥 ResNet 모델 생성
resnet50 = keras.models.Sequential([
    keras.applications.resnet.ResNet50(
        include_top = False,
        weights = 'imagenet',
        input_shape = (224, 224, 3),
        pooling = 'avg'
    ),
    keras.layers.Dense(num_classes, activation='softmax')
])

# %%
# ResNet+Augmentation 모델 생성
aug_resnet50 = keras.models.Sequential([
    keras.applications.resnet.ResNet50(
        include_top = False,
        weights = 'imagenet',
        input_shape = (224, 224, 3),
        pooling = 'avg'
    ),
    keras.layers.Dense(num_classes, activation='softmax')
])

# %%
# ResNet+Cutmix 모델 생성
cutmix_resnet50 = keras.models.Sequential([
    keras.applications.resnet.ResNet50(
        include_top = False,
        weights = 'imagenet',
        input_shape = (224, 224, 3),
        pooling = 'avg'
    ),
    keras.layers.Dense(num_classes, activation='softmax')
])

# %%
# ResNet+Mixup 모델 생성
mixup_resnet50 = keras.models.Sequential([
    keras.applications.resnet.ResNet50(
        include_top = False,
        weights = 'imagenet',
        input_shape = (224, 224, 3),
        pooling = 'avg'
    ),
    keras.layers.Dense(num_classes, activation='softmax')
])

# %%
# 데이터를 아까 만든 각종 Augmentation을 해주는 함수에 집어넣는다
(ds_train, ds_test), ds_info = tfds.load(
    'stanford_dogs',
    split=['train', 'test'],
    as_supervised=True,
    shuffle_files=True,
    with_info=True,
)

ds_train_no_aug = apply_normalize_on_dataset(ds_train, with_aug=False)
ds_train_aug = apply_normalize_on_dataset(ds_train, with_aug=True)
ds_train_cutmix = apply_normalize_on_dataset(ds_train, with_aug = True, with_cutmix=True)
ds_train_mixup = apply_normalize_on_dataset(ds_train, with_aug = True, with_mixup=True)
ds_test = apply_normalize_on_dataset(ds_test, is_test = True)

# %% [markdown]
# ## 4.3 모델 훈련하기

# %%
# 같은 환경에서 실험하기 위해 시드를 고정시켜주고, 체크포인트 경로를 설정해준다
tf.random.set_seed(999)

import os
CPR = os.path.dirname(os.path.abspath('__file__')) + r'/checkpoint/'

# %%
# 그냥 ResNet 모델 컴파일 및 학습
resnet50.compile(
    loss = 'categorical_crossentropy',
    optimizer = tf.keras.optimizers.SGD(lr=0.01),
    metrics = ['accuracy']
)

CPR = checkpointRes + 'res50.ckpt'
res_callbacks = tf.keras.callbacks.ModelCheckpoint(filepath = CPR,
                                                  save_weights_only = True, verbose = 1)

history_resnet50 = resnet50.fit(
    ds_train_no_aug,
    steps_per_epoch = int(ds_info.splits['train'].num_examples/16),
    validation_steps = int(ds_info.splits['test'].num_examples/16),
    epochs = 10,
    validation_data = ds_test,
    verbose = 1,
    use_multiprocessing = True,
    callbacks = [res_callbacks]
)
# Out:
# Epoch 1/10
# 750/750 [==============================] - ETA: 0s - loss: 2.1984 - accuracy: 0.4428
# Epoch 00001: saving model to /home/asnkmgsk/workplace/Week12/data/checkpoint/res50.ckpt
# 750/750 [==============================] - 121s 162ms/step - loss: 2.1984 - accuracy: 0.4428 - val_loss: 3.5714 - val_accuracy: 0.1739
# Epoch 2/10
# 750/750 [==============================] - ETA: 0s - loss: 0.7669 - accuracy: 0.7893
# Epoch 00002: saving model to /home/asnkmgsk/workplace/Week12/data/checkpoint/res50.ckpt
# 750/750 [==============================] - 121s 161ms/step - loss: 0.7669 - accuracy: 0.7893 - val_loss: 1.1160 - val_accuracy: 0.6747
# Epoch 3/10
# 750/750 [==============================] - ETA: 0s - loss: 0.2832 - accuracy: 0.9367
# Epoch 00003: saving model to /home/asnkmgsk/workplace/Week12/data/checkpoint/res50.ckpt
# 750/750 [==============================] - 117s 156ms/step - loss: 0.2832 - accuracy: 0.9367 - val_loss: 1.0355 - val_accuracy: 0.7038
# Epoch 4/10
# 750/750 [==============================] - ETA: 0s - loss: 0.0940 - accuracy: 0.9873
# Epoch 00004: saving model to /home/asnkmgsk/workplace/Week12/data/checkpoint/res50.ckpt
# 750/750 [==============================] - 118s 157ms/step - loss: 0.0940 - accuracy: 0.9873 - val_loss: 0.9584 - val_accuracy: 0.7227
# Epoch 5/10
# 750/750 [==============================] - ETA: 0s - loss: 0.0479 - accuracy: 0.9962
# Epoch 00005: saving model to /home/asnkmgsk/workplace/Week12/data/checkpoint/res50.ckpt
# 750/750 [==============================] - 117s 156ms/step - loss: 0.0479 - accuracy: 0.9962 - val_loss: 0.9397 - val_accuracy: 0.7343
# Epoch 6/10
# 750/750 [==============================] - ETA: 0s - loss: 0.0301 - accuracy: 0.9977
# Epoch 00006: saving model to /home/asnkmgsk/workplace/Week12/data/checkpoint/res50.ckpt
# 750/750 [==============================] - 117s 156ms/step - loss: 0.0301 - accuracy: 0.9977 - val_loss: 0.9303 - val_accuracy: 0.7406
# Epoch 7/10
# 750/750 [==============================] - ETA: 0s - loss: 0.0162 - accuracy: 0.9988
# Epoch 00007: saving model to /home/asnkmgsk/workplace/Week12/data/checkpoint/res50.ckpt
# 750/750 [==============================] - 117s 156ms/step - loss: 0.0162 - accuracy: 0.9988 - val_loss: 0.9224 - val_accuracy: 0.7472
# Epoch 8/10
# 750/750 [==============================] - ETA: 0s - loss: 0.0086 - accuracy: 0.9998
# Epoch 00008: saving model to /home/asnkmgsk/workplace/Week12/data/checkpoint/res50.ckpt
# 750/750 [==============================] - 117s 157ms/step - loss: 0.0086 - accuracy: 0.9998 - val_loss: 0.9289 - val_accuracy: 0.7486
# Epoch 9/10
# 750/750 [==============================] - ETA: 0s - loss: 0.0057 - accuracy: 1.0000
# Epoch 00009: saving model to /home/asnkmgsk/workplace/Week12/data/checkpoint/res50.ckpt
# 750/750 [==============================] - 117s 156ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.9351 - val_accuracy: 0.7487
# Epoch 10/10
# 750/750 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 1.0000
# Epoch 00010: saving model to /home/asnkmgsk/workplace/Week12/data/checkpoint/res50.ckpt
# 750/750 [==============================] - 117s 156ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.9482 - val_accuracy: 0.7472

# %%
# ResNet+Augmentation 모델 컴파일 및 학습
aug_resnet50.compile(
    loss = 'categorical_crossentropy',
    optimizer = tf.keras.optimizers.SGD(lr=0.01),
    metrics = ['accuracy']
)

aug_resnet50_checkpoint_path = CPR + 'aug_res50.ckpt'
aug_resnet_callbacks = tf.keras.callbacks.ModelCheckpoint(filepath = aug_resnet50_checkpoint_path,
                                                  save_weights_only = True,
                                                  verbose=1)


history_aug_resnet50 = aug_resnet50.fit(
    ds_train_aug,
    steps_per_epoch = int(ds_info.splits['train'].num_examples/16),
    validation_steps = int(ds_info.splits['test'].num_examples/16),
    epochs = 10,
    validation_data = ds_test,
    verbose = 1,
    use_multiprocessing = True,
    callbacks = [aug_resnet_callbacks]
)
# Out:
# Epoch 1/10
# 750/750 [==============================] - ETA: 0s - loss: 2.2534 - accuracy: 0.4356
# Epoch 00001: saving model to /home/asnkmgsk/workplace/Week12/checkpoint/aug_res50.ckpt
# 750/750 [==============================] - 120s 160ms/step - loss: 2.2534 - accuracy: 0.4356 - val_loss: 2.9173 - val_accuracy: 0.2836
# Epoch 2/10
# 750/750 [==============================] - ETA: 0s - loss: 0.9635 - accuracy: 0.7255
# Epoch 00002: saving model to /home/asnkmgsk/workplace/Week12/checkpoint/aug_res50.ckpt
# 750/750 [==============================] - 120s 160ms/step - loss: 0.9635 - accuracy: 0.7255 - val_loss: 1.2301 - val_accuracy: 0.6475
# Epoch 3/10
# 750/750 [==============================] - ETA: 0s - loss: 0.5678 - accuracy: 0.8393
# Epoch 00003: saving model to /home/asnkmgsk/workplace/Week12/checkpoint/aug_res50.ckpt
# 750/750 [==============================] - 120s 160ms/step - loss: 0.5678 - accuracy: 0.8393 - val_loss: 1.1861 - val_accuracy: 0.6694
# Epoch 4/10
# 750/750 [==============================] - ETA: 0s - loss: 0.3178 - accuracy: 0.9193
# Epoch 00004: saving model to /home/asnkmgsk/workplace/Week12/checkpoint/aug_res50.ckpt
# 750/750 [==============================] - 120s 160ms/step - loss: 0.3178 - accuracy: 0.9193 - val_loss: 0.9766 - val_accuracy: 0.7169
# Epoch 5/10
# 750/750 [==============================] - ETA: 0s - loss: 0.1746 - accuracy: 0.9622
# Epoch 00005: saving model to /home/asnkmgsk/workplace/Week12/checkpoint/aug_res50.ckpt
# 750/750 [==============================] - 121s 161ms/step - loss: 0.1746 - accuracy: 0.9622 - val_loss: 1.0894 - val_accuracy: 0.6952
# Epoch 6/10
# 750/750 [==============================] - ETA: 0s - loss: 0.0862 - accuracy: 0.9858
# Epoch 00006: saving model to /home/asnkmgsk/workplace/Week12/checkpoint/aug_res50.ckpt
# 750/750 [==============================] - 120s 161ms/step - loss: 0.0862 - accuracy: 0.9858 - val_loss: 0.9849 - val_accuracy: 0.7271
# Epoch 7/10
# 750/750 [==============================] - ETA: 0s - loss: 0.0669 - accuracy: 0.9903
# Epoch 00007: saving model to /home/asnkmgsk/workplace/Week12/checkpoint/aug_res50.ckpt
# 750/750 [==============================] - 120s 161ms/step - loss: 0.0669 - accuracy: 0.9903 - val_loss: 0.9615 - val_accuracy: 0.7304
# Epoch 8/10
# 750/750 [==============================] - ETA: 0s - loss: 0.0347 - accuracy: 0.9963
# Epoch 00008: saving model to /home/asnkmgsk/workplace/Week12/checkpoint/aug_res50.ckpt
# 750/750 [==============================] - 120s 161ms/step - loss: 0.0347 - accuracy: 0.9963 - val_loss: 0.9313 - val_accuracy: 0.7406
# Epoch 9/10
# 750/750 [==============================] - ETA: 0s - loss: 0.0260 - accuracy: 0.9978
# Epoch 00009: saving model to /home/asnkmgsk/workplace/Week12/checkpoint/aug_res50.ckpt
# 750/750 [==============================] - 121s 161ms/step - loss: 0.0260 - accuracy: 0.9978 - val_loss: 0.9544 - val_accuracy: 0.7361
# Epoch 10/10
# 750/750 [==============================] - ETA: 0s - loss: 0.0153 - accuracy: 0.9988
# Epoch 00010: saving model to /home/asnkmgsk/workplace/Week12/checkpoint/aug_res50.ckpt
# 750/750 [==============================] - 126s 167ms/step - loss: 0.0153 - accuracy: 0.9988 - val_loss: 0.9102 - val_accuracy: 0.7540

# %%
# ResNet+Cumix 모델 컴파일 및 학습
cutmix_resnet50.compile(
    loss = 'categorical_crossentropy',
    optimizer = tf.keras.optimizers.SGD(lr=0.01),
    metrics = ['accuracy']
)

cutmix_checkpoint_path = CPR + 'cutmmix.ckpt'
cutmix_callbacks = tf.keras.callbacks.ModelCheckpoint(filepath = cutmix_checkpoint_path,
                                                     save_weights_only = True, verbose = 1)


history_cutmix_resnet50 = cutmix_resnet50.fit(
    ds_train_cutmix,
    steps_per_epoch = int(ds_info.splits['train'].num_examples/16),
    validation_steps = int(ds_info.splits['test'].num_examples/16),
    epochs = 10,
    validation_data = ds_test,
    verbose = 1,
    use_multiprocessing = True,
    callbacks = [cutmix_callbacks]
)
# Out:
# Epoch 1/10
# 750/750 [==============================] - ETA: 0s - loss: 3.8230 - accuracy: 0.2137
# Epoch 00001: saving model to /home/asnkmgsk/workplace/Week12/checkpoint/cutmmix.ckpt
# 750/750 [==============================] - 121s 162ms/step - loss: 3.8230 - accuracy: 0.2137 - val_loss: 3.1401 - val_accuracy: 0.2460
# Epoch 2/10
# 750/750 [==============================] - ETA: 0s - loss: 2.9835 - accuracy: 0.4135
# Epoch 00002: saving model to /home/asnkmgsk/workplace/Week12/checkpoint/cutmmix.ckpt
# 750/750 [==============================] - 118s 157ms/step - loss: 2.9835 - accuracy: 0.4135 - val_loss: 1.3733 - val_accuracy: 0.6172
# Epoch 3/10
# 750/750 [==============================] - ETA: 0s - loss: 2.7284 - accuracy: 0.4923
# Epoch 00003: saving model to /home/asnkmgsk/workplace/Week12/checkpoint/cutmmix.ckpt
# 750/750 [==============================] - 118s 158ms/step - loss: 2.7284 - accuracy: 0.4923 - val_loss: 1.3694 - val_accuracy: 0.6213
# Epoch 4/10
# 750/750 [==============================] - ETA: 0s - loss: 2.5404 - accuracy: 0.5546
# Epoch 00004: saving model to /home/asnkmgsk/workplace/Week12/checkpoint/cutmmix.ckpt
# 750/750 [==============================] - 118s 158ms/step - loss: 2.5404 - accuracy: 0.5546 - val_loss: 1.2345 - val_accuracy: 0.6568
# Epoch 5/10
# 750/750 [==============================] - ETA: 0s - loss: 2.3994 - accuracy: 0.5948
# Epoch 00005: saving model to /home/asnkmgsk/workplace/Week12/checkpoint/cutmmix.ckpt
# 750/750 [==============================] - 119s 158ms/step - loss: 2.3994 - accuracy: 0.5948 - val_loss: 1.2126 - val_accuracy: 0.6673
# Epoch 6/10
# 750/750 [==============================] - ETA: 0s - loss: 2.2851 - accuracy: 0.6359
# Epoch 00006: saving model to /home/asnkmgsk/workplace/Week12/checkpoint/cutmmix.ckpt
# 750/750 [==============================] - 119s 158ms/step - loss: 2.2851 - accuracy: 0.6359 - val_loss: 1.2791 - val_accuracy: 0.6481
# Epoch 7/10
# 750/750 [==============================] - ETA: 0s - loss: 2.2067 - accuracy: 0.6593
# Epoch 00007: saving model to /home/asnkmgsk/workplace/Week12/checkpoint/cutmmix.ckpt
# 750/750 [==============================] - 119s 158ms/step - loss: 2.2067 - accuracy: 0.6593 - val_loss: 1.2431 - val_accuracy: 0.6659
# Epoch 8/10
# 750/750 [==============================] - ETA: 0s - loss: 2.1259 - accuracy: 0.6780
# Epoch 00008: saving model to /home/asnkmgsk/workplace/Week12/checkpoint/cutmmix.ckpt
# 750/750 [==============================] - 119s 158ms/step - loss: 2.1259 - accuracy: 0.6780 - val_loss: 1.3756 - val_accuracy: 0.6276
# Epoch 9/10
# 750/750 [==============================] - ETA: 0s - loss: 2.0594 - accuracy: 0.6940
# Epoch 00009: saving model to /home/asnkmgsk/workplace/Week12/checkpoint/cutmmix.ckpt
# 750/750 [==============================] - 119s 158ms/step - loss: 2.0594 - accuracy: 0.6940 - val_loss: 1.0932 - val_accuracy: 0.7053
# Epoch 10/10
# 750/750 [==============================] - ETA: 0s - loss: 2.0014 - accuracy: 0.7107
# Epoch 00010: saving model to /home/asnkmgsk/workplace/Week12/checkpoint/cutmmix.ckpt
# 750/750 [==============================] - 119s 158ms/step - loss: 2.0014 - accuracy: 0.7107 - val_loss: 1.2195 - val_accuracy: 0.6712

# %%
# ResNet+Mixup 모델 컴파일 및 학습
mixup_resnet50.compile(
    loss = 'categorical_crossentropy',
    optimizer = tf.keras.optimizers.SGD(lr=0.01),
    metrics = ['accuracy']
)

mixup_checkpoint_path = CPR + 'mixup.ckpt'
mixup_callbacks = tf.keras.callbacks.ModelCheckpoint(filepath = mixup_checkpoint_path,
                                                    save_weights_only = True, verbose = 1)

history_mixup_resnet50 = mixup_resnet50.fit(
    ds_train_mixup,
    steps_per_epoch = int(ds_info.splits['train'].num_examples/16),
    validation_steps = int(ds_info.splits['test'].num_examples/16),
    epochs = 10,
    validation_data = ds_test,
    verbose = 1,
    use_multiprocessing = True,
    callbacks = [mixup_callbacks]
)
# Out:
# Epoch 1/10
# 750/750 [==============================] - ETA: 0s - loss: 3.7315 - accuracy: 0.2457
# Epoch 00001: saving model to /home/asnkmgsk/workplace/Week12/checkpoint/mixup.ckpt
# 750/750 [==============================] - 114s 152ms/step - loss: 3.7315 - accuracy: 0.2457 - val_loss: 3.4607 - val_accuracy: 0.1930
# Epoch 2/10
# 750/750 [==============================] - ETA: 0s - loss: 2.9250 - accuracy: 0.4551
# Epoch 00002: saving model to /home/asnkmgsk/workplace/Week12/checkpoint/mixup.ckpt
# 750/750 [==============================] - 115s 153ms/step - loss: 2.9250 - accuracy: 0.4551 - val_loss: 1.5414 - val_accuracy: 0.5743
# Epoch 3/10
# 750/750 [==============================] - ETA: 0s - loss: 2.6604 - accuracy: 0.5458
# Epoch 00003: saving model to /home/asnkmgsk/workplace/Week12/checkpoint/mixup.ckpt
# 750/750 [==============================] - 115s 153ms/step - loss: 2.6604 - accuracy: 0.5458 - val_loss: 1.4014 - val_accuracy: 0.6128
# Epoch 4/10
# 750/750 [==============================] - ETA: 0s - loss: 2.5074 - accuracy: 0.6066
# Epoch 00004: saving model to /home/asnkmgsk/workplace/Week12/checkpoint/mixup.ckpt
# 750/750 [==============================] - 115s 153ms/step - loss: 2.5074 - accuracy: 0.6066 - val_loss: 1.5086 - val_accuracy: 0.5892
# Epoch 5/10
# 750/750 [==============================] - ETA: 0s - loss: 2.3940 - accuracy: 0.6544
# Epoch 00005: saving model to /home/asnkmgsk/workplace/Week12/checkpoint/mixup.ckpt
# 750/750 [==============================] - 115s 153ms/step - loss: 2.3940 - accuracy: 0.6544 - val_loss: 1.4675 - val_accuracy: 0.6009
# Epoch 6/10
# 750/750 [==============================] - ETA: 0s - loss: 2.2898 - accuracy: 0.6886
# Epoch 00006: saving model to /home/asnkmgsk/workplace/Week12/checkpoint/mixup.ckpt
# 750/750 [==============================] - 115s 153ms/step - loss: 2.2898 - accuracy: 0.6886 - val_loss: 1.2109 - val_accuracy: 0.6637
# Epoch 7/10
# 750/750 [==============================] - ETA: 0s - loss: 2.2241 - accuracy: 0.7122
# Epoch 00007: saving model to /home/asnkmgsk/workplace/Week12/checkpoint/mixup.ckpt
# 750/750 [==============================] - 115s 153ms/step - loss: 2.2241 - accuracy: 0.7122 - val_loss: 1.5179 - val_accuracy: 0.5993
# Epoch 8/10
# 750/750 [==============================] - ETA: 0s - loss: 2.1750 - accuracy: 0.7358
# Epoch 00008: saving model to /home/asnkmgsk/workplace/Week12/checkpoint/mixup.ckpt
# 750/750 [==============================] - 115s 153ms/step - loss: 2.1750 - accuracy: 0.7358 - val_loss: 1.1792 - val_accuracy: 0.6769
# Epoch 9/10
# 750/750 [==============================] - ETA: 0s - loss: 2.0902 - accuracy: 0.7641
# Epoch 00009: saving model to /home/asnkmgsk/workplace/Week12/checkpoint/mixup.ckpt
# 750/750 [==============================] - 115s 153ms/step - loss: 2.0902 - accuracy: 0.7641 - val_loss: 1.2057 - val_accuracy: 0.6767
# Epoch 10/10
# 750/750 [==============================] - ETA: 0s - loss: 2.0745 - accuracy: 0.7653
# Epoch 00010: saving model to /home/asnkmgsk/workplace/Week12/checkpoint/mixup.ckpt
# 750/750 [==============================] - 115s 153ms/step - loss: 2.0745 - accuracy: 0.7653 - val_loss: 1.2941 - val_accuracy: 0.6470

# %% [markdown]
# ## 4.4 훈련 과정 시각화하기

# %%
plt.figure(figsize = (12, 10))

plt.plot(history_resnet50.history['val_accuracy'], 'r')
plt.plot(history_aug_resnet50.history['val_accuracy'], 'b')
plt.plot(history_cutmix_resnet50.history['val_accuracy'], 'y')
plt.plot(history_mixup_resnet50.history['val_accuracy'], 'g')

plt.title("Validation Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(['No Augmentation', 'Augmentation', 'Augmentation + Cutmix', 'Augmentation + Mixup'], loc = 'upper left')
plt.grid(True)
plt.ylim(0.4, 0.77)

plt.show()
