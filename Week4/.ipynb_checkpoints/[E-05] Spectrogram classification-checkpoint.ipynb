# %%
import numpy as np
import os
import os

data_path = os.getenv("HOME")+'/aiffel/speech_recognition/data/speech_wav_8000.npz'
speech_data = np.load(data_path)

# %%
print("Wave data shape : ", speech_data["wav_vals"].shape)
print("Label data shape : ", speech_data["label_vals"].shape)
# Out:
# Wave data shape :  (50620, 8000)
# Label data shape :  (50620, 1)

# %%
import IPython.display as ipd
import random

# 데이터 선택 (랜덤하게 선택하고 있으니, 여러번 실행해 보세요)
rand = random.randint(0, len(speech_data["wav_vals"]))
print("rand num : ", rand)

sr = 8000 # 1초동안 재생되는 샘플의 갯수
data = speech_data["wav_vals"][rand]
print("Wave data shape : ", data.shape)
print("label : ", speech_data["label_vals"][rand])

ipd.Audio(data, rate=sr)
# Out:
# rand num :  5494
# Wave data shape :  (8000,)
# label :  ['left']
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
target_list = ['yes', 'no', 'up', 'down', 'left', 'right', 'on', 'off', 'stop', 'go']

label_value = target_list
label_value.append('unknown')
label_value.append('silence')

print('LABEL : ', label_value)

new_label_value = dict()
for i, l in enumerate(label_value):
    new_label_value[l] = i
label_value = new_label_value

print('Indexed LABEL : ', new_label_value)
# Out:
# LABEL :  ['yes', 'no', 'up', 'down', 'left', 'right', 'on', 'off', 'stop', 'go', 'unknown', 'silence']
# Indexed LABEL :  {'yes': 0, 'no': 1, 'up': 2, 'down': 3, 'left': 4, 'right': 5, 'on': 6, 'off': 7, 'stop': 8, 'go': 9, 'unknown': 10, 'silence': 11}

# %%
temp = []
for v in speech_data["label_vals"][:30000]:
    temp.append(label_value[v[0]])
label_data = np.array(temp)

label_data
# Out:
# array([3, 3, 3, ..., 7, 7, 7])

# %%
import librosa

def wav2spec(wav, fft_size=258): # spectrogram shape을 맞추기위해서 size 변형
    D = np.abs(librosa.stft(wav, n_fft=fft_size))
    return D

# %%
spec = wav2spec(data)
print("Waveform shape : ",data.shape)
print("Spectrogram shape : ",spec.shape)
# Out:
# Waveform shape :  (8000,)
# Spectrogram shape :  (130, 126)

# %%
import librosa.display
from matplotlib import pyplot as plt

librosa.display.specshow(librosa.amplitude_to_db(spec, ref=np.max), x_axis='time')
plt.title('Power spectrogram')
plt.colorbar(format='%+2.0f dB')
plt.xticks(range(0, 1))
plt.tight_layout()
plt.show()

# %%
spec.shape
# Out:
# (130, 126)

# %%
spec = []
spec_temp = []

for w in speech_data["wav_vals"][:30000]:
    spec_temp.append(wav2spec(w))
    
spec = np.array(spec_temp)
print(spec.shape)

'''
spec = list(map(wav2spec, speech_data['wav_vals']))
spec = np.array(spec)
spec.shape
'''
# Out:
# (30000, 130, 126)
# "\nspec = list(map(wav2spec, speech_data['wav_vals']))\nspec = np.array(spec)\nspec.shape\n"

# %%
from sklearn.model_selection import train_test_split

train_wav, test_wav, train_label, test_label = train_test_split(spec, 
                                                                label_data, 
                                                                test_size=0.1,
                                                                shuffle=True)

# %%
print("train data : ", train_wav.shape)
print("train labels : ", train_label.shape)
print("test data : ", test_wav.shape)
print("test labels : ", test_label.shape)
# Out:
# train data :  (27000, 130, 126)
# train labels :  (27000,)
# test data :  (3000, 130, 126)
# test labels :  (3000,)

# %%
batch_size = 120
max_epochs = 15

# the save point
checkpoint_dir = os.getenv('HOME')+'/aiffel/speech_recognition/models/wav'

checkpoint_dir
# Out:
# '/home/ssac3/aiffel/speech_recognition/models/wav'

# %%
def one_hot_label(wav, label):
    label = tf.one_hot(label, depth=12)
    return wav, label
# Out:
# ✅

# %%
import tensorflow as tf

# for train
train_dataset = tf.data.Dataset.from_tensor_slices((train_wav, train_label))
train_dataset = train_dataset.map(one_hot_label)
train_dataset = train_dataset.repeat().batch(batch_size=batch_size)
print(train_dataset)

# for test
test_dataset = tf.data.Dataset.from_tensor_slices((test_wav, test_label))
test_dataset = test_dataset.map(one_hot_label)
test_dataset = test_dataset.batch(batch_size=batch_size)
print(test_dataset)
# Out:
# <BatchDataset shapes: ((None, 130, 126), (None, 12)), types: (tf.float32, tf.float32)>
# <BatchDataset shapes: ((None, 130, 126), (None, 12)), types: (tf.float32, tf.float32)>

# %%
from tensorflow.keras import layers

input_tensor = layers.Input(shape=(130, 126))

x = layers.Conv1D(32, 9, padding='same', activation='relu')(input_tensor)
x = layers.Conv1D(32, 9, padding='same', activation='relu')(x)
x = layers.MaxPool1D()(x)

x = layers.Conv1D(64, 9, padding='same', activation='relu')(x)
x = layers.Conv1D(64, 9, padding='same', activation='relu')(x)
x = layers.MaxPool1D()(x)

x = layers.Conv1D(128, 9, padding='same', activation='relu')(x)
x = layers.Conv1D(128, 9, padding='same', activation='relu')(x)
x = layers.Conv1D(128, 9, padding='same', activation='relu')(x)
x = layers.MaxPool1D()(x)

x = layers.Conv1D(256, 9, padding='same', activation='relu')(x)
x = layers.Conv1D(256, 9, padding='same', activation='relu')(x)
x = layers.Conv1D(256, 9, padding='same', activation='relu')(x)
x = layers.MaxPool1D()(x)
x = layers.Dropout(0.3)(x)

x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)

output_tensor = layers.Dense(12)(x)

modelSpec = tf.keras.Model(input_tensor, output_tensor)

modelSpec.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 130, 126)]        0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 130, 32)           36320
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 130, 32)           9248
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 65, 32)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 65, 64)            18496
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 65, 64)            36928
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 32, 64)            0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 32, 128)           73856
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 32, 128)           147584
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 32, 128)           147584
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 16, 128)           0
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 16, 256)           295168
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 16, 256)           590080
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 16, 256)           590080
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 8, 256)            0
# _________________________________________________________________
# dropout (Dropout)            (None, 8, 256)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               524544
# _________________________________________________________________
# batch_normalization (BatchNo (None, 256)               1024
# _________________________________________________________________
# activation (Activation)      (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 12)                3084
# =================================================================
# Total params: 2,473,996
# Trainable params: 2,473,484
# Non-trainable params: 512
# _________________________________________________________________

# %%
optimizer=tf.keras.optimizers.Adam(1e-4)
modelSpec.compile(loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
             optimizer=optimizer,
             metrics=['accuracy'])
# Out:
# ✅

# %%
cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_dir,
                                                 save_weights_only=True,
                                                 monitor='val_loss',
                                                 mode='auto',
                                                 save_best_only=True,
                                                 verbose=1)
# Out:
# ✅

# %%
#30분 내외 소요 (메모리 사용량에 주의해 주세요.)
history_wav = modelSpec.fit(train_dataset, epochs=max_epochs,
                    steps_per_epoch=len(train_wav) // batch_size,
                    validation_data=test_dataset,
                    validation_steps=len(test_wav) // batch_size,
                    callbacks=[cp_callback]
                    )
# Out:
# Epoch 1/15
# 224/225 [============================>.] - ETA: 0s - loss: 1.8028 - accuracy: 0.3804
# Epoch 00001: val_loss improved from inf to 2.12987, saving model to /home/ssac3/aiffel/speech_recognition/models/wav
# 225/225 [==============================] - 4s 18ms/step - loss: 1.8001 - accuracy: 0.3813 - val_loss: 2.1299 - val_accuracy: 0.5343
# Epoch 2/15
# 222/225 [============================>.] - ETA: 0s - loss: 1.0612 - accuracy: 0.6253
# Epoch 00002: val_loss improved from 2.12987 to 1.16782, saving model to /home/ssac3/aiffel/speech_recognition/models/wav
# 225/225 [==============================] - 4s 17ms/step - loss: 1.0591 - accuracy: 0.6263 - val_loss: 1.1678 - val_accuracy: 0.6767
# Epoch 3/15
# 222/225 [============================>.] - ETA: 0s - loss: 0.7516 - accuracy: 0.7393
# Epoch 00003: val_loss improved from 1.16782 to 0.68762, saving model to /home/ssac3/aiffel/speech_recognition/models/wav
# 225/225 [==============================] - 4s 18ms/step - loss: 0.7515 - accuracy: 0.7395 - val_loss: 0.6876 - val_accuracy: 0.7623
# Epoch 4/15
# 225/225 [==============================] - ETA: 0s - loss: 0.5383 - accuracy: 0.8181
# Epoch 00004: val_loss improved from 0.68762 to 0.51287, saving model to /home/ssac3/aiffel/speech_recognition/models/wav
# 225/225 [==============================] - 4s 19ms/step - loss: 0.5383 - accuracy: 0.8181 - val_loss: 0.5129 - val_accuracy: 0.8223
# Epoch 5/15
# 225/225 [==============================] - ETA: 0s - loss: 0.3977 - accuracy: 0.8676
# Epoch 00005: val_loss improved from 0.51287 to 0.43816, saving model to /home/ssac3/aiffel/speech_recognition/models/wav
# 225/225 [==============================] - 4s 17ms/step - loss: 0.3977 - accuracy: 0.8676 - val_loss: 0.4382 - val_accuracy: 0.8510
# Epoch 6/15
# 225/225 [==============================] - ETA: 0s - loss: 0.3123 - accuracy: 0.8993
# Epoch 00006: val_loss improved from 0.43816 to 0.39724, saving model to /home/ssac3/aiffel/speech_recognition/models/wav
# 225/225 [==============================] - 4s 17ms/step - loss: 0.3123 - accuracy: 0.8993 - val_loss: 0.3972 - val_accuracy: 0.8653
# Epoch 7/15
# 222/225 [============================>.] - ETA: 0s - loss: 0.2497 - accuracy: 0.9199
# Epoch 00007: val_loss improved from 0.39724 to 0.38711, saving model to /home/ssac3/aiffel/speech_recognition/models/wav
# 225/225 [==============================] - 4s 18ms/step - loss: 0.2497 - accuracy: 0.9200 - val_loss: 0.3871 - val_accuracy: 0.8650
# Epoch 8/15
# 224/225 [============================>.] - ETA: 0s - loss: 0.2045 - accuracy: 0.9368
# Epoch 00008: val_loss improved from 0.38711 to 0.35761, saving model to /home/ssac3/aiffel/speech_recognition/models/wav
# 225/225 [==============================] - 4s 19ms/step - loss: 0.2041 - accuracy: 0.9370 - val_loss: 0.3576 - val_accuracy: 0.8780
# Epoch 9/15
# 222/225 [============================>.] - ETA: 0s - loss: 0.1711 - accuracy: 0.9466
# Epoch 00009: val_loss improved from 0.35761 to 0.34337, saving model to /home/ssac3/aiffel/speech_recognition/models/wav
# 225/225 [==============================] - 4s 18ms/step - loss: 0.1712 - accuracy: 0.9467 - val_loss: 0.3434 - val_accuracy: 0.8850
# Epoch 10/15
# 222/225 [============================>.] - ETA: 0s - loss: 0.1446 - accuracy: 0.9541
# Epoch 00010: val_loss improved from 0.34337 to 0.31118, saving model to /home/ssac3/aiffel/speech_recognition/models/wav
# 225/225 [==============================] - 4s 18ms/step - loss: 0.1446 - accuracy: 0.9542 - val_loss: 0.3112 - val_accuracy: 0.8963
# Epoch 11/15
# 224/225 [============================>.] - ETA: 0s - loss: 0.1225 - accuracy: 0.9633
# Epoch 00011: val_loss did not improve from 0.31118
# 225/225 [==============================] - 4s 18ms/step - loss: 0.1223 - accuracy: 0.9634 - val_loss: 0.3668 - val_accuracy: 0.8817
# Epoch 12/15
# 223/225 [============================>.] - ETA: 0s - loss: 0.1085 - accuracy: 0.9672
# Epoch 00012: val_loss did not improve from 0.31118
# 225/225 [==============================] - 4s 16ms/step - loss: 0.1087 - accuracy: 0.9672 - val_loss: 0.3729 - val_accuracy: 0.8767
# Epoch 13/15
# 223/225 [============================>.] - ETA: 0s - loss: 0.0969 - accuracy: 0.9703
# Epoch 00013: val_loss improved from 0.31118 to 0.30549, saving model to /home/ssac3/aiffel/speech_recognition/models/wav
# 225/225 [==============================] - 4s 17ms/step - loss: 0.0970 - accuracy: 0.9703 - val_loss: 0.3055 - val_accuracy: 0.9033
# Epoch 14/15
# 225/225 [==============================] - ETA: 0s - loss: 0.0858 - accuracy: 0.9736
# Epoch 00014: val_loss did not improve from 0.30549
# 225/225 [==============================] - 4s 17ms/step - loss: 0.0858 - accuracy: 0.9736 - val_loss: 0.3695 - val_accuracy: 0.8797
# Epoch 15/15
# 224/225 [============================>.] - ETA: 0s - loss: 0.0777 - accuracy: 0.9759
# Epoch 00015: val_loss did not improve from 0.30549
# 225/225 [==============================] - 4s 19ms/step - loss: 0.0777 - accuracy: 0.9758 - val_loss: 0.3820 - val_accuracy: 0.8850
# ✅

# %%
import matplotlib.pyplot as plt

acc = history_wav.history['accuracy']
val_acc = history_wav.history['val_accuracy']

loss=history_wav.history['loss']
val_loss=history_wav.history['val_loss']

epochs_range = range(len(acc))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
print("✅")
# Out:
# ✅

# %%
modelSpec.load_weights(checkpoint_dir)
print("✅")
# Out:
# ✅

# %%
results = modelSpec.evaluate(test_dataset)
print("✅")
# Out:
# 25/25 [==============================] - 0s 7ms/step - loss: 0.3055 - accuracy: 0.9033
# ✅

# %%
# loss
print("loss value: {:.3f}".format(results[0]))
# accuracy
print("accuracy value: {:.4f}%".format(results[1]*100))
print("✅")
# Out:
# loss value: 0.305
# accuracy value: 90.3333%
# ✅

# %%
inv_label_value = {v: k for k, v in label_value.items()}
batch_index = np.random.choice(len(test_wav), size=1, replace=False)

batch_xs = test_wav[batch_index]
batch_ys = test_label[batch_index]
y_pred_ = modelSpec(batch_xs, training=False)

print("label : ", str(inv_label_value[batch_ys[0]]))

# ipd.Audio(batch_xs.reshape(8000,), rate=800)
# Out:
# label :  off

# %%
if np.argmax(y_pred_) == batch_ys[0]:
    print("y_pred: " + str(inv_label_value[np.argmax(y_pred_)]) + '(Correct!)')
else:
    print("y_pred: " + str(inv_label_value[np.argmax(y_pred_)]) + '(Incorrect!)')
print("✅")
# Out:
# y_pred: right(Correct!)
# ✅

# %%
input_tensor = layers.Input(shape=(130, 126))

x = layers.Conv1D(32, 9, padding='same', activation='relu')(input_tensor)
x = layers.Conv1D(32, 9, padding='same', activation='relu')(x)
skip_1 = layers.MaxPool1D()(x)

x = layers.Conv1D(64, 9, padding='same', activation='relu')(skip_1)
x = layers.Conv1D(64, 9, padding='same', activation='relu')(x)
x = tf.concat([x, skip_1], -1)
skip_2 = layers.MaxPool1D()(x)

x = layers.Conv1D(128, 9, padding='same', activation='relu')(skip_2)
x = layers.Conv1D(128, 9, padding='same', activation='relu')(x)
x = layers.Conv1D(128, 9, padding='same', activation='relu')(x)
x = tf.concat([x, skip_2], -1)
skip_3 = layers.MaxPool1D()(x)

x = layers.Conv1D(256, 9, padding='same', activation='relu')(skip_3)
x = layers.Conv1D(256, 9, padding='same', activation='relu')(x)
x = layers.Conv1D(256, 9, padding='same', activation='relu')(x)
x = tf.concat([x, skip_3], -1)
x = layers.MaxPool1D()(x)
x = layers.Dropout(0.3)(x)

x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)

output_tensor = layers.Dense(12)(x)

modelSpec_skip = tf.keras.Model(input_tensor, output_tensor)

modelSpec_skip.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 130, 126)]   0
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 130, 32)      36320       input_2[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 130, 32)      9248        conv1d_10[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 65, 32)       0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 65, 64)       18496       max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 65, 64)       36928       conv1d_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat (TensorFlowO [(None, 65, 96)]     0           conv1d_13[0][0]
#                                                                  max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 32, 96)       0           tf_op_layer_concat[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 32, 128)      110720      max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 32, 128)      147584      conv1d_14[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 32, 128)      147584      conv1d_15[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_1 (TensorFlo [(None, 32, 224)]    0           conv1d_16[0][0]
#                                                                  max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_6 (MaxPooling1D)  (None, 16, 224)      0           tf_op_layer_concat_1[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 16, 256)      516352      max_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 16, 256)      590080      conv1d_17[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 16, 256)      590080      conv1d_18[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_2 (TensorFlo [(None, 16, 480)]    0           conv1d_19[0][0]
#                                                                  max_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_7 (MaxPooling1D)  (None, 8, 480)       0           tf_op_layer_concat_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 8, 480)       0           max_pooling1d_7[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 3840)         0           dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 256)          983296      flatten_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256)          1024        dense_2[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256)          0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 12)           3084        activation_1[0][0]
# ==================================================================================================
# Total params: 3,190,796
# Trainable params: 3,190,284
# Non-trainable params: 512
# __________________________________________________________________________________________________

# %%
optimizer=tf.keras.optimizers.Adam(1e-4)
modelSpec_skip.compile(loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
             optimizer=optimizer,
             metrics=['accuracy'])
print("✅")
# Out:
# ✅

# %%
# the save point
checkpoint_dir = os.getenv('HOME')+'/aiffel/speech_recognition/models/wav_skip'

cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_dir,
                                                 save_weights_only=True,
                                                 monitor='val_loss',
                                                 mode='auto',
                                                 save_best_only=True,
                                                 verbose=1)
print("✅")
# Out:
# ✅

# %%
#30분 내외 소요
history_wav_skip = modelSpec_skip.fit(train_dataset, epochs=max_epochs,
                    steps_per_epoch=len(train_wav) // batch_size,
                    validation_data=test_dataset,
                    validation_steps=len(test_wav) // batch_size,
                    callbacks=[cp_callback]
                    )
print("✅")
# Out:
# Epoch 1/15
# 224/225 [============================>.] - ETA: 0s - loss: 1.8877 - accuracy: 0.3544
# Epoch 00001: val_loss improved from inf to 1.56183, saving model to /home/ssac3/aiffel/speech_recognition/models/wav_skip
# 225/225 [==============================] - 5s 21ms/step - loss: 1.8849 - accuracy: 0.3554 - val_loss: 1.5618 - val_accuracy: 0.5023
# Epoch 2/15
# 225/225 [==============================] - ETA: 0s - loss: 1.1888 - accuracy: 0.5836
# Epoch 00002: val_loss improved from 1.56183 to 1.02602, saving model to /home/ssac3/aiffel/speech_recognition/models/wav_skip
# 225/225 [==============================] - 4s 19ms/step - loss: 1.1888 - accuracy: 0.5836 - val_loss: 1.0260 - val_accuracy: 0.6410
# Epoch 3/15
# 223/225 [============================>.] - ETA: 0s - loss: 0.8142 - accuracy: 0.7187
# Epoch 00003: val_loss improved from 1.02602 to 0.69635, saving model to /home/ssac3/aiffel/speech_recognition/models/wav_skip
# 225/225 [==============================] - 4s 19ms/step - loss: 0.8131 - accuracy: 0.7189 - val_loss: 0.6963 - val_accuracy: 0.7543
# Epoch 4/15
# 224/225 [============================>.] - ETA: 0s - loss: 0.5697 - accuracy: 0.8055
# Epoch 00004: val_loss improved from 0.69635 to 0.53289, saving model to /home/ssac3/aiffel/speech_recognition/models/wav_skip
# 225/225 [==============================] - 4s 19ms/step - loss: 0.5690 - accuracy: 0.8057 - val_loss: 0.5329 - val_accuracy: 0.8127
# Epoch 5/15
# 223/225 [============================>.] - ETA: 0s - loss: 0.4258 - accuracy: 0.8554
# Epoch 00005: val_loss improved from 0.53289 to 0.49215, saving model to /home/ssac3/aiffel/speech_recognition/models/wav_skip
# 225/225 [==============================] - 4s 19ms/step - loss: 0.4253 - accuracy: 0.8554 - val_loss: 0.4921 - val_accuracy: 0.8317
# Epoch 6/15
# 224/225 [============================>.] - ETA: 0s - loss: 0.3340 - accuracy: 0.8881
# Epoch 00006: val_loss improved from 0.49215 to 0.41603, saving model to /home/ssac3/aiffel/speech_recognition/models/wav_skip
# 225/225 [==============================] - 4s 19ms/step - loss: 0.3337 - accuracy: 0.8882 - val_loss: 0.4160 - val_accuracy: 0.8573
# Epoch 7/15
# 225/225 [==============================] - ETA: 0s - loss: 0.2709 - accuracy: 0.9120
# Epoch 00007: val_loss improved from 0.41603 to 0.37991, saving model to /home/ssac3/aiffel/speech_recognition/models/wav_skip
# 225/225 [==============================] - 4s 19ms/step - loss: 0.2709 - accuracy: 0.9120 - val_loss: 0.3799 - val_accuracy: 0.8737
# Epoch 8/15
# 223/225 [============================>.] - ETA: 0s - loss: 0.2229 - accuracy: 0.9292
# Epoch 00008: val_loss improved from 0.37991 to 0.35189, saving model to /home/ssac3/aiffel/speech_recognition/models/wav_skip
# 225/225 [==============================] - 4s 19ms/step - loss: 0.2227 - accuracy: 0.9291 - val_loss: 0.3519 - val_accuracy: 0.8840
# Epoch 9/15
# 225/225 [==============================] - ETA: 0s - loss: 0.1854 - accuracy: 0.9416
# Epoch 00009: val_loss did not improve from 0.35189
# 225/225 [==============================] - 4s 18ms/step - loss: 0.1854 - accuracy: 0.9416 - val_loss: 0.3554 - val_accuracy: 0.8873
# Epoch 10/15
# 224/225 [============================>.] - ETA: 0s - loss: 0.1591 - accuracy: 0.9512
# Epoch 00010: val_loss improved from 0.35189 to 0.35039, saving model to /home/ssac3/aiffel/speech_recognition/models/wav_skip
# 225/225 [==============================] - 4s 19ms/step - loss: 0.1587 - accuracy: 0.9514 - val_loss: 0.3504 - val_accuracy: 0.8887
# Epoch 11/15
# 223/225 [============================>.] - ETA: 0s - loss: 0.1331 - accuracy: 0.9603
# Epoch 00011: val_loss did not improve from 0.35039
# 225/225 [==============================] - 4s 19ms/step - loss: 0.1326 - accuracy: 0.9604 - val_loss: 0.3869 - val_accuracy: 0.8797
# Epoch 12/15
# 224/225 [============================>.] - ETA: 0s - loss: 0.1144 - accuracy: 0.9669
# Epoch 00012: val_loss improved from 0.35039 to 0.32753, saving model to /home/ssac3/aiffel/speech_recognition/models/wav_skip
# 225/225 [==============================] - 4s 19ms/step - loss: 0.1142 - accuracy: 0.9669 - val_loss: 0.3275 - val_accuracy: 0.8943
# Epoch 13/15
# 223/225 [============================>.] - ETA: 0s - loss: 0.1009 - accuracy: 0.9707
# Epoch 00013: val_loss improved from 0.32753 to 0.28265, saving model to /home/ssac3/aiffel/speech_recognition/models/wav_skip
# 225/225 [==============================] - 4s 19ms/step - loss: 0.1007 - accuracy: 0.9707 - val_loss: 0.2826 - val_accuracy: 0.9077
# Epoch 14/15
# 223/225 [============================>.] - ETA: 0s - loss: 0.0929 - accuracy: 0.9714
# Epoch 00014: val_loss improved from 0.28265 to 0.26337, saving model to /home/ssac3/aiffel/speech_recognition/models/wav_skip
# 225/225 [==============================] - 4s 19ms/step - loss: 0.0928 - accuracy: 0.9714 - val_loss: 0.2634 - val_accuracy: 0.9177
# Epoch 15/15
# 223/225 [============================>.] - ETA: 0s - loss: 0.0828 - accuracy: 0.9756
# Epoch 00015: val_loss did not improve from 0.26337
# 225/225 [==============================] - 4s 19ms/step - loss: 0.0826 - accuracy: 0.9757 - val_loss: 0.2652 - val_accuracy: 0.9153
# ✅

# %%
import matplotlib.pyplot as plt

acc = history_wav_skip.history['accuracy']
val_acc = history_wav_skip.history['val_accuracy']

loss=history_wav_skip.history['loss']
val_loss=history_wav_skip.history['val_loss']

epochs_range = range(len(acc))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
print("✅")
# Out:
# ✅

# %%
# Evaluation 

modelSpec_skip.load_weights(checkpoint_dir)
results = modelSpec_skip.evaluate(test_dataset)

# loss
print("loss value: {:.3f}".format(results[0]))
# accuracy
print("accuracy value: {:.4f}%".format(results[1]*100))
print("✅")
# Out:
# 25/25 [==============================] - 0s 7ms/step - loss: 0.2634 - accuracy: 0.9177
# loss value: 0.263
# accuracy value: 91.7667%
# ✅

# %%
# Test 

inv_label_value = {v: k for k, v in label_value.items()}
batch_index = np.random.choice(len(test_wav), size=1, replace=False)

batch_xs = test_wav[batch_index]
batch_ys = test_label[batch_index]
y_pred_ = modelSpec_skip(batch_xs, training=False)

print("label : ", str(inv_label_value[batch_ys[0]]))
# Out:
# label :  go

# %%
if np.argmax(y_pred_) == batch_ys[0]:
    print("y_pred: " + str(inv_label_value[np.argmax(y_pred_)]) + '(Correct!)')
else:
    print("y_pred: " + str(inv_label_value[np.argmax(y_pred_)]) + '(Incorrect!)')
print("✅")
# Out:
# y_pred: go(Correct!)
# ✅
